# %%
import glob
import math
import numpy as np
import os
import pandas as pd

from datetime import timedelta

# %%
adidas_detail_data_1_150 = pd.read_csv('../data/detail/adidas_detail_data_1_150.csv')
adidas_detail_data_150_300 = pd.read_csv('../data/detail/adidas_detail_data_150_300.csv')
adidas_detail_data_300_450 = pd.read_csv('../data/detail/adidas_detail_data_300_450.csv')
adidas_detail_data_450_650 = pd.read_csv('../data/detail/adidas_detail_data_450_650.csv')
adidas_detail_data_650_900 = pd.read_csv('../data/detail/adidas_detail_data_650_900.csv')
adidas_detail_data_900_1200 = pd.read_csv('../data/detail/adidas_detail_data_900_1200.csv')
adidas_detail_data_1200_1600 = pd.read_csv('../data/detail/adidas_detail_data_1200_1600.csv')
adidas_detail_data_1600_2000 = pd.read_csv('../data/detail/adidas_detail_data_1600_2000.csv')
adidas_detail_data_2000_2500 = pd.read_csv('../data/detail/adidas_detail_data_2000_2500.csv')
adidas_detail_data_2500_2700 = pd.read_csv('../data/detail/adidas_detail_data_2500_2700.csv')
adidas_detail_data_2700_2800 = pd.read_csv('../data/detail/adidas_detail_data_2700_2800.csv')
adidas_detail_data_2800_2900 = pd.read_csv('../data/detail/adidas_detail_data_2800_2900.csv')
adidas_detail_data_2900_3050 = pd.read_csv('../data/detail/adidas_detail_data_2900_3050.csv')
adidas_detail_data_3050_3250 = pd.read_csv('../data/detail/adidas_detail_data_3050_3250.csv')
adidas_detail_data_3250_3500 = pd.read_csv('../data/detail/adidas_detail_data_3250_3500.csv')
adidas_detail_data_3500_3600 = pd.read_csv('../data/detail/adidas_detail_data_3500_3600.csv')
adidas_detail_data_3600_3613 = pd.read_csv('../data/detail/adidas_detail_data_3600_3613.csv')
adidas_detail_data_3613_3614 = pd.read_csv('../data/detail/adidas_detail_data_3613_3614.csv')
adidas_detail_data_3615_3622 = pd.read_csv('../data/detail/adidas_detail_data_3615_3622.csv')
adidas_detail_data_3623_3796 = pd.read_csv('../data/detail/adidas_detail_data_3623_3796.csv')
adidas_detail_data_3797_4000 = pd.read_csv('../data/detail/adidas_detail_data_3797_4000.csv')
adidas_detail_data_4000_4300 = pd.read_csv('../data/detail/adidas_detail_data_4000_4300.csv')
adidas_detail_data_4300_4600 = pd.read_csv('../data/detail/adidas_detail_data_4300_4600.csv') 
adidas_detail_data_4600_4800 = pd.read_csv('../data/detail/adidas_detail_data_4600_4800.csv')
adidas_detail_data_4800_4900 = pd.read_csv('../data/detail/adidas_detail_data_4800_4900.csv')
adidas_detail_data_4900_5200 = pd.read_csv('../data/detail/adidas_detail_data_4900_5200.csv')
adidas_detail_data_5200_5500 = pd.read_csv('../data/detail/adidas_detail_data_5200_5500.csv')
adidas_detail_data_5500_5550 = pd.read_csv('../data/detail/adidas_detail_data_5500_5550.csv')
adidas_detail_data_5550_5674 = pd.read_csv('../data/detail/adidas_detail_data_5550_5674.csv')
adidas_detail_data_5675_last = pd.read_csv('../data/detail/adidas_detail_data_5675_last.csv')

df = pd.concat([adidas_detail_data_1_150, adidas_detail_data_150_300,adidas_detail_data_300_450, 
                           adidas_detail_data_450_650, adidas_detail_data_650_900, adidas_detail_data_900_1200, 
                           adidas_detail_data_1200_1600, adidas_detail_data_1600_2000, adidas_detail_data_2000_2500, 
                           adidas_detail_data_2500_2700, adidas_detail_data_2700_2800, adidas_detail_data_2800_2900, 
                           adidas_detail_data_2900_3050, adidas_detail_data_3050_3250, adidas_detail_data_3250_3500, 
                           adidas_detail_data_3500_3600, adidas_detail_data_3600_3613, adidas_detail_data_3613_3614, 
                           adidas_detail_data_3615_3622, adidas_detail_data_3623_3796, adidas_detail_data_3797_4000, 
                           adidas_detail_data_4000_4300, adidas_detail_data_4300_4600, adidas_detail_data_4600_4800, 
                           adidas_detail_data_4800_4900, adidas_detail_data_4900_5200, adidas_detail_data_5200_5500, 
                           adidas_detail_data_5500_5550, adidas_detail_data_5550_5674, adidas_detail_data_5675_last])

#インデックスをリセット
df = df.reset_index()
df = df.drop(df.columns[[0]], axis=1)
df
# Out:
#                                              id   brand  \
# 0     adidas-yeezy-boost-350-v2-multi-color-f-f  adidas
# 1     adidas-yeezy-boost-350-v2-multi-color-f-f  adidas
# 2     adidas-yeezy-boost-350-v2-multi-color-f-f  adidas
# 3     adidas-yeezy-boost-350-v2-multi-color-f-f  adidas
# 4     adidas-yeezy-boost-350-v2-multi-color-f-f  adidas
# ...                                         ...     ...
# 5809  adidas-yeezy-boost-350-v2-multi-color-f-f  adidas
# 5810  adidas-yeezy-boost-350-v2-multi-color-f-f  adidas
# 5811  adidas-yeezy-boost-350-v2-multi-color-f-f  adidas
# 5812  adidas-yeezy-boost-350-v2-multi-color-f-f  adidas
# 5813  adidas-yeezy-boost-350-v2-multi-color-f-f  adidas
#
#                                         product_name condition last_sale  \
# 0                adidas dame 5 core black shock pink       New     ¥6400
# 1     adidas n3xt l3v3l cream white bahia light blue       New    ¥10500
# ...

# %%
#この方がスマートだが順番がばらばらになる

# csv_files = glob.glob(r'C:\Users\Kei\diveintocode-ml\capstone_project\data\detail/*.csv')

# data_list = []
# for file in csv_files:
#     data_list.append(pd.read_csv(file))
    
# df = pd.concat(data_list)

# #インデックスをリセット
# df = df.reset_index()
# df = df.drop(df.columns[[0]], axis=1)
# df

# %%
#idを割り振りなおす

adidas_df = pd.read_csv('adidas_url.csv')
adidas_df
# Out:
#                                           Product ID  Model Type Size Type  \
# 0                adidas-dame-5-core-black-shock-pink  Basketball       Men
# 1     adidas-n3xt-l3v3l-cream-white-bahia-light-blue  Basketball       Men
# 2              adidas-don-issue-1-amazing-spider-man  Basketball       Men
# 3                 adidas-dame-5-marvel-black-panther  Basketball       Men
# 4             adidas-harden-ls-2-buckle-triple-black  Basketball       Men
# ...                                              ...         ...       ...
# 5813                adidas-yeezy-boost-350-v2-eliada       Yeezy       Men
# 5814         adidas-yeezy-boost-380-azure-reflective       Yeezy       Men
# 5815    adidas-yeezy-boost-350-v2-israfil-reflective       Yeezy       Men
# 5816         adidas-yeezy-boost-380-lmnte-reflective       Yeezy       Men
# 5817       adidas-yeezy-boost-350-v2-multi-color-f-f       Yeezy       Men
#
#                                               Image URL  \
# ...

# %%
#余分な行を削除

adidas_df = adidas_df.drop(adidas_df.index[[3614, 3622, 3796, 5674]]).reset_index()
adidas_df
# Out:
#       index                                      Product ID  Model Type  \
# 0         0             adidas-dame-5-core-black-shock-pink  Basketball
# 1         1  adidas-n3xt-l3v3l-cream-white-bahia-light-blue  Basketball
# 2         2           adidas-don-issue-1-amazing-spider-man  Basketball
# 3         3              adidas-dame-5-marvel-black-panther  Basketball
# 4         4          adidas-harden-ls-2-buckle-triple-black  Basketball
# ...     ...                                             ...         ...
# 5809   5813                adidas-yeezy-boost-350-v2-eliada       Yeezy
# 5810   5814         adidas-yeezy-boost-380-azure-reflective       Yeezy
# 5811   5815    adidas-yeezy-boost-350-v2-israfil-reflective       Yeezy
# 5812   5816         adidas-yeezy-boost-380-lmnte-reflective       Yeezy
# 5813   5817       adidas-yeezy-boost-350-v2-multi-color-f-f       Yeezy
#
#      Size Type                                          Image URL  \
# ...

# %%
product_id = adidas_df.iloc[:, 1]
product_id
# Out:
# 0                  adidas-dame-5-core-black-shock-pink
# 1       adidas-n3xt-l3v3l-cream-white-bahia-light-blue
# 2                adidas-don-issue-1-amazing-spider-man
# 3                   adidas-dame-5-marvel-black-panther
# 4               adidas-harden-ls-2-buckle-triple-black
#                              ...
# 5809                  adidas-yeezy-boost-350-v2-eliada
# 5810           adidas-yeezy-boost-380-azure-reflective
# 5811      adidas-yeezy-boost-350-v2-israfil-reflective
# 5812           adidas-yeezy-boost-380-lmnte-reflective
# 5813         adidas-yeezy-boost-350-v2-multi-color-f-f
# Name: Product ID, Length: 5814, dtype: object

# %%
df['id'] = product_id
df
# Out:
#                                                   id   brand  \
# 0                adidas-dame-5-core-black-shock-pink  adidas
# 1     adidas-n3xt-l3v3l-cream-white-bahia-light-blue  adidas
# 2              adidas-don-issue-1-amazing-spider-man  adidas
# 3                 adidas-dame-5-marvel-black-panther  adidas
# 4             adidas-harden-ls-2-buckle-triple-black  adidas
# ...                                              ...     ...
# 5809                adidas-yeezy-boost-350-v2-eliada  adidas
# 5810         adidas-yeezy-boost-380-azure-reflective  adidas
# 5811    adidas-yeezy-boost-350-v2-israfil-reflective  adidas
# 5812         adidas-yeezy-boost-380-lmnte-reflective  adidas
# 5813       adidas-yeezy-boost-350-v2-multi-color-f-f  adidas
#
#                                         product_name condition last_sale  \
# 0                adidas dame 5 core black shock pink       New     ¥6400
# 1     adidas n3xt l3v3l cream white bahia light blue       New    ¥10500
# ...

# %%
#csvファイルとして書き出し

# adidas_detail.to_csv('adidas_detail.csv')

# %%
#dfの列を50まで省略せずに表示
pd.set_option('display.max_columns', 50)

#ユニークな要素のみ抽出
# adidas_detail = pd.read_csv('adidas_detail.csv')
adidas_detail_unique = df[~df['product_name'].duplicated()]
adidas_detail_unique = adidas_detail_unique.reset_index()
adidas_detail_unique = adidas_detail_unique.drop(adidas_detail_unique.columns[[0]], axis=1)

#'--'をNaNに置換
adidas_detail_unique = adidas_detail_unique.replace('--', math.nan)

#'\'を削除
adidas_detail_unique['last_sale'] = adidas_detail_unique['last_sale'].str[1:]
adidas_detail_unique['lowest_ask'] = adidas_detail_unique['lowest_ask'].str[1:]
adidas_detail_unique['highest_bid'] = adidas_detail_unique['highest_bid'].str[1:]

#'7,600'→'7600'
adidas_detail_unique['avg_sale_price_12_month'] = adidas_detail_unique[
    'avg_sale_price_12_month'].str.replace(',', '')

#数値の欠損値を0埋め
adidas_detail_unique[['last_sale', 'last_sale_size', 'lowest_ask', 'highest_bid', 
                      'retail_price', 'high_52_week', 'low_52_week', 'low_12_month_trade', 
                      'high_12_month_trade', 'volatility','num_sales_12_month', 
                      'price_premium_12_month', 'avg_sale_price_12_month']] = adidas_detail_unique[[
                      'last_sale', 'last_sale_size', 'lowest_ask', 'highest_bid', 
                      'retail_price', 'high_52_week', 'low_52_week', 'low_12_month_trade', 
                      'high_12_month_trade', 'volatility','num_sales_12_month', 
                      'price_premium_12_month', 'avg_sale_price_12_month']].fillna(0)

#intに変換
adidas_detail_unique[['last_sale', 'lowest_ask', 'highest_bid', 'retail_price', 'high_52_week', 
                      'low_52_week', 'low_12_month_trade', 'high_12_month_trade', 
                      'num_sales_12_month', 'avg_sale_price_12_month']] = adidas_detail_unique[[
                      'last_sale', 'lowest_ask', 'highest_bid', 'retail_price', 'high_52_week', 
                      'low_52_week', 'low_12_month_trade', 'high_12_month_trade', 
                      'num_sales_12_month', 'avg_sale_price_12_month']].astype(int)

#floatに変換
#'last_sale_size', 
adidas_detail_unique[['volatility', 'price_premium_12_month']] = adidas_detail_unique[[
    'volatility', 'price_premium_12_month']].astype(float)

#日付に変換
adidas_detail_unique['release_date'] = pd.to_datetime(adidas_detail_unique['release_date'], format='%m/%d/%Y')

#0埋めした欠損値を欠損値NaNに戻す
adidas_detail_unique = adidas_detail_unique.replace(0, math.nan)
adidas_detail_unique[['since_last_sale_dollar', 'since_last_sale_percent']] = adidas_detail_unique[[
    'since_last_sale_dollar', 'since_last_sale_percent']].fillna(0)

#目的変数avg_sale_price_12_monthに欠損値をもつものを消去
adidas_detail_unique = adidas_detail_unique.dropna(subset=['avg_sale_price_12_month'])

#retail_priceに欠損値をもつものを消去
adidas_detail_unique = adidas_detail_unique.dropna(subset=['retail_price'])

#'volatility', 'release_date'に欠損値をもつものを消去
# adidas_detail_unique = adidas_detail_unique.dropna(subset=['volatility', 'release_date'])

#発売後の日数を追加(スクレイプ日2020年10月18日との差)
adidas_detail_unique['period'] = pd.to_datetime('20201018') - adidas_detail_unique['release_date']

#timedelta型から整数型に変換
adidas_detail_unique['period'] = adidas_detail_unique['period'] / timedelta(days=1)
adidas_detail_unique

#モデル名追加
model_name = adidas_detail_unique['product_name'].str.split(expand=True)
adidas_detail_unique['model'] = model_name.iloc[:, 1]
adidas_detail_unique

#定価を円に
adidas_detail_unique['retail_price'] = adidas_detail_unique['retail_price'] *104.7

adidas_detail_unique
# Out:
#                                                   id   brand  \
# 0                adidas-dame-5-core-black-shock-pink  adidas
# 1     adidas-n3xt-l3v3l-cream-white-bahia-light-blue  adidas
# 2              adidas-don-issue-1-amazing-spider-man  adidas
# 3                 adidas-dame-5-marvel-black-panther  adidas
# 4             adidas-harden-ls-2-buckle-triple-black  adidas
# ...                                              ...     ...
# 5598             adidas-yeezy-boost-950-pirate-black  adidas
# 5599             adidas-yeezy-boost-380-calcite-glow  adidas
# 5605                   adidas-yeezy-boost-950-peyote  adidas
# 5606                adidas-yeezy-500-shadow-black-ff  adidas
# 5607  adidas-yeezy-boost-380-calcite-glow-reflective  adidas
#
#                                           product_name condition  last_sale  \
# 0                  adidas dame 5 core black shock pink       New     6400.0
# 1       adidas n3xt l3v3l cream white bahia light blue       New    10500.0
# ...

# %%
#csvファイルとして書き出し

# adidas_detail.to_csv('adidas_detail.csv')

# %% [markdown]
# ## 画像があり、詳細データを持つものを抽出

# %%
 # ファイル数を調べたいフォルダのパス
img_path = r"C:\Users\Kei\Desktop\adidas_img" 
 
# フォルダ内の全ファイル名をリスト化
img_files = os.listdir(img_path)
 
img_id_list = []
for img in img_files:
    img = img.split('.')
    id = img[0]
    img_id_list.append(id)
    
len(img_id_list)
# Out:
# 5348

# %%
#id列を取り出しリストに変換

adidas_detail_list = adidas_detail_unique['id'].values.tolist()

# %%
#画像、テーブルデータの両方もつものを抽出

img_table_and = set(img_id_list) & set(adidas_detail_list)
len(img_table_and)
# Out:
# 3852

# %%
img_table_and_df = pd.DataFrame(img_table_and)
img_table_and_df.columns = ['id']
img_table_and_df
# Out:
#                                                      id
# 0     adidas-rs-replicant-ozweego-raf-simons-colonia...
# 1                   adidas-eqt-running-guidance-solebox
# 2                adidas-ultra-boost-reigning-champ-grey
# 3                               adidas-adistar-comp-a-d
# 4       adidas-ultra-boost-20-core-black-night-metallic
# ...                                                 ...
# 3847             adidas-sobakov-clear-orange-core-black
# 3848              adidas-deerupt-cloud-white-core-black
# 3849                  adidas-ultra-boost-light-bone-2-0
# 3850      adidas-predator-precision-turf-blue-white-red
# 3851          adidas-eqt-running-guidance-93-sneakers76
#
# [3852 rows x 1 columns]

# %%
adidas_final_df = pd.merge(img_table_and_df, adidas_detail_unique, on='id')
adidas_final_df = adidas_final_df.reindex(columns=['id', 'brand', 'model', 'product_name', 'condition', 
                                                   'last_sale', 'last_sale_size', 'lowest_ask', 'highest_bid', 
                                                   'since_last_sale_dollar', 'since_last_sale_percent', 
                                                   'colorway', 'retail_price', 'release_date', 'high_52_week', 
                                                   'low_52_week', 'low_12_month_trade', 'high_12_month_trade', 
                                                   'volatility', 'num_sales_12_month', 'price_premium_12_month', 
                                                   'avg_sale_price_12_month', 'period'])
adidas_final_df
# Out:
#                                                      id   brand     model  \
# 0     adidas-rs-replicant-ozweego-raf-simons-colonia...  adidas        rs
# 1                   adidas-eqt-running-guidance-solebox  adidas       eqt
# 2                adidas-ultra-boost-reigning-champ-grey  adidas     ultra
# 3                               adidas-adistar-comp-a-d  adidas   adistar
# 4       adidas-ultra-boost-20-core-black-night-metallic  adidas     ultra
# ...                                                 ...     ...       ...
# 3847             adidas-sobakov-clear-orange-core-black  adidas   sobakov
# 3848              adidas-deerupt-cloud-white-core-black  adidas   deerupt
# 3849                  adidas-ultra-boost-light-bone-2-0  adidas     ultra
# 3850      adidas-predator-precision-turf-blue-white-red  adidas  predator
# 3851          adidas-eqt-running-guidance-93-sneakers76  adidas       eqt
#
#                                            product_name condition  last_sale  \
# ...

# %%
adidas_final_df.to_csv('adidas_final_df.csv', index=False)
